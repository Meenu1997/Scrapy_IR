 'https://ta.wikipedia.org/wiki/%E0%AE%9A%E0%AE%BF%E0%AE%B0%E0%AF%87%E0%AE%AF%E0%AE%BE_%E0%AE%9A%E0%AE%B0%E0%AE%A9%E0%AF%8D',
 'https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%82%E0%AE%9C%E0%AE%BE_(%E0%AE%A8%E0%AE%9F%E0%AE%BF%E0%AE%95%E0%AF%88)',
 'https://ta.wikipedia.org/wiki/%E0%AE%B0%E0%AE%BE%E0%AE%B7%E0%AF%8D%E0%AE%AE%E0%AE%BF%E0%AE%95%E0%AE%BE_%E0%AE%AE%E0%AE%A8%E0%AF%8D%E0%AE%A4%E0%AE%A3%E0%AF%8D%E0%AE%A3%E0%AE%BE']

# %%
len(links)
# Out:
# 105

# %%
import requests

# %%
from bs4 import BeautifulSoup
import csv

# %%
csv_columns = ['பெயர்','பிறந்த திகதி','பிறந்த இடம் ','தொழில்','வாழ்க்கை துணை','பெற்றோர் ','சுருக்கம் ','உள்ளடக்கம்']

# %%
def paragraph(soup_new):
    para1 = '-'
    para2 = '-'

    try:
        parser_contents = soup_new.find('div',{"class":"mw-parser-output"}).contents
        for i in parser_contents:
            if i.name == 'p':
                if para1 == '-':
                    para1 = i.text.strip()
                    continue
                if para2 == '-':
                    para2 = i.text.strip()
                    break
        # for para_index in range(len(list_para)):
        #     if para_index == 0:
        #         para1 = list_para[para_index].text.strip()
        #     else:
        #         para_last+=(list_para[para_index].text.strip()+ str('\n'))
        # para2 = para_last
        return (para1, para2)

    except AttributeError:
        return (para1, para2)

# %%
def birth(soup_new):
    birthdate = '-'
    birthplace = '-'
    try:
        info_box = soup_new.find('table',{'class':'infobox'})
        table_row_list = info_box.findAll('tr')
    except TypeError or AttributeError :
        return(birthdate, birthplace)

    for tr in table_row_list:
        try:
            if ((tr.th.text).strip() == 'பிறப்பு'):
                if tr.td.findAll('span',{'class':'bday'}):
                    birthdate = tr.td.find('span',{'class':'bday'}).text
                if  tr.td.findAll('span',{'class':'birthplace'}):
                    birthplace = tr.td.find('span',{'class':'birthplace'}).text
                else:
                    try:
                        string_br= str(tr.td)
                        if '<br/>' in string_br:
                            splitted_with_break = string_br.split('<br/>')
                            birthplace = (BeautifulSoup(splitted_with_break[-1],"html.parser").text.strip())
                            if birthplace == '':
                                birthplace = '-'
                    except AttributeError:
                        continue
        except AttributeError or TypeError:
            continue
    return (birthdate, birthplace)

# %%
def name(new_soup):
  actor_name = new_soup.find('h1', {'class':'firstHeading'}).text
  final_name = actor_name.split("(")
  return final_name[0]

# %%
vijay_link = 'https://ta.wikipedia.org/wiki/%E0%AE%B5%E0%AE%BF%E0%AE%9C%E0%AE%AF%E0%AF%8D_(%E0%AE%A8%E0%AE%9F%E0%AE%BF%E0%AE%95%E0%AE%B0%E0%AF%8D)'
get_url = requests.get(vijay_link)
get_text = get_url.text
soup_new = BeautifulSoup(get_text, "html.parser")

info_box = soup_new.find('table',{'class':'infobox'})

table_row_list = info_box.findAll('tr')

for i in table_row_list:
  try:
    if ((i.th.text).strip() == 'துணைவர்'):
      print(i.td.text)
      break
    else:
      print("no")
  except AttributeError:
    continue

# %%
def occupation(soup_new):
  occ = 'திரைப்பட நடிகர்'
  try:
    info_box = soup_new.find('table',{'class':'infobox'})
    table_row_list = info_box.findAll('tr')
  except TypeError or AttributeError :
    return(occ)
  for i in table_row_list:
    try:
      if ((i.th.text).strip() == 'தொழில்' or (i.th.text).strip() == 'பணி'):
        print(i.td.text)
        occ = i.td.text
        return (occ)
    except AttributeError or TypeError:
      continue
  return occ

# %%
def partner(soup_new):
  par = '-'
  try:
    info_box = soup_new.find('table',{'class':'infobox'})
    table_row_list = info_box.findAll('tr')
  except TypeError or AttributeError :
    return(par)
  for i in table_row_list:
    try:
      if ((i.th.text).strip() == 'துணைவர்'):
        print(i.td.text)
        par = i.td.text
        return (par)
        # break
      # else:
        # print("no")
    except AttributeError or TypeError:
      continue
  return par

# %%
def parents(soup_new):
  par = '-'
  try:
    info_box = soup_new.find('table',{'class':'infobox'})
    table_row_list = info_box.findAll('tr')
  except TypeError or AttributeError :
    return(par)
  for i in table_row_list:
    try:
      if ((i.th.text).strip() == 'பெற்றோர்'):
        print(i.td.text)
        par = i.td.text
        return (par)
        # break
      # else:
        # print("no")
    except AttributeError or TypeError:
      continue
  return par

# %%
dict_data= []
for i in range(len(links)):
  dict = {}
  response_new = requests.get(url= links[i])
  soup_new = BeautifulSoup(response_new.content, 'html.parser')
  try:
    bday,birthplace = birth(soup_new)
    para1,para2 = paragraph(soup_new)
    actor_name = name(soup_new)
    occ = occupation(soup_new)
    par = partner(soup_new)
    m_d = parents(soup_new)

  except AttributeError or TypeError:
    bday = '-'
    birthplace = '-'
    actor_name = '-'
    # occ = 'திரைப்பட நடிகர்'

  dict[csv_columns[1]] = bday
  dict[csv_columns[2]] = birthplace
  dict[csv_columns[6]] = para1
  dict[csv_columns[7]] = para2
  dict[csv_columns[0]] = actor_name
  dict[csv_columns[3]] = occ
  dict[csv_columns[4]] = par
  dict[csv_columns[5]] = m_d

  dict_data.append(dict)


csv_file = 'data.csv'

try:
    with open(csv_file,'w') as csv_file:
        writer = csv.DictWriter(csv_file,fieldnames=csv_columns)
        writer.writeheader()
        for data in dict_data:
            writer.writerow(data)

except IOError:
    print("I/O error")

# %%
import pandas as pd

# %%
path = '/content/data.csv'

# %%
output_scrap = pd.read_csv(path)

# %%
output_scrap.T
# Out:
#                                                              0    ...                                                104
# பெயர்                                                ஸ்ரீகாந்த்   ...                                  ராஷ்மிகா மந்தண்ணா
# பிறந்த திகதி                                          1979-02-28  ...                                         1996-04-05
# பிறந்த இடம்                           சென்னை, தமிழ்நாடு, இந்தியா  ...                   விராஜ்பேட்டை, கர்நாடகம், இந்தியா
# தொழில்                                           திரைப்பட நடிகர்  ...                                              நடிகை
# வாழ்க்கை துணை                                                  -  ...                                             கிஷோக்
# பெற்றோர்                                                       -  ...                                                  -
# சுருக்கம்      ஸ்ரீகாந்த்  (ஆங்கில மொழி: Srikanth, பிறப்பு: ப...  ...  ரஷ்மிகா மந்தண்ணா, இந்தியத் திரைப்பட நடிகை ஆவார...
# ...
